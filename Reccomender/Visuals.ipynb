# %%
from Visualizer import Visualizer
import pandas as pd

# %%
df = pd.read_csv("./Data/feature-data/calm_features.csv")
viz = Visualizer()
calm_chart = viz.makeRadar(df, "Calm")

# %%
df = pd.read_csv("./Data/feature-data/energetic_features.csv")
viz = Visualizer()
calm_chart = viz.makeRadar(df, "Energetic")

# %%
df = pd.read_csv("./Data/feature-data/sad-features.csv")
viz = Visualizer()
calm_chart = viz.makeRadar(df, "Sad")

# %%
df = pd.read_csv("./Data/feature-data/happy_features.csv")
viz = Visualizer()
calm_chart = viz.makeRadar(df, "Happy")
