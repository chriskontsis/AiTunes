# %%
import SpotifyAPIWrapper
import Visualizer
import pandas as pd
import numpy as np
import spotipy
import time

# %%
spotify_wrapper = SpotifyAPIWrapper.SpotifyAPIWrapper()
user_playlist_df = spotify_wrapper.getUsersPlaylists('spotify')
user_playlist_df
# Out:
#                         name                    uris
# 0           Today’s Top Hits  37i9dQZF1DXcBWIGoYBM5M
# 1                  RapCaviar  37i9dQZF1DX0XUsuxWHRQd
# 2                Hot Country  37i9dQZF1DX1lVhptIYRda
# 3                Viva Latino  37i9dQZF1DX10zKzsJ2jva
# 4           New Music Friday  37i9dQZF1DX4JAvHpjipBk
# 5             Peaceful Piano  37i9dQZF1DX4sWSpwq3LiO
# 6                      RNB X  37i9dQZF1DX4SBhb3fqCJd
# 7              Rock Classics  37i9dQZF1DWXRqgorJj26U
# 8                       mint  37i9dQZF1DX4dyzvuaRJ0n
# 9                     MARROW  37i9dQZF1DXcF6B6QPhFDv
# 10          New Music Friday  37i9dQZF1DWXJfnUiYjUKT
# 11                 just hits  37i9dQZF1DXcRXFNfZr7Tp
# 12             All Out 2000s  37i9dQZF1DX4o1oenSJRJd
# 13               All Out 90s  37i9dQZF1DXbTxeAdrVG2l
# 14               All Out 80s  37i9dQZF1DX4UtSsGT1Sbe
# 15               All Out 70s  37i9dQZF1DWTJ7xPn4vNaz
# 16               All Out 60s  37i9dQZF1DXaKIA8E7WcJj
# 17               All Out 50s  37i9dQZF1DWSV3Tk4GO2fq
# 18             Soft Pop Hits  37i9dQZF1DWTwnEm1IYyoj
# 19               Signed XOXO  37i9dQZF1DX2A29LI7xHn1
# 20            Most Necessary  37i9dQZF1DX2RxBh64BHjQ
# 21               Gold School  37i9dQZF1DWVA1Gq4XHa6U
# 22                 Get Turnt  37i9dQZF1DWY4xHQp97fN6
# 23                    B.A.E.  37i9dQZF1DWX3387IZmjNa
# 24              African Heat  37i9dQZF1DWYkaDif7Ztbp
# 25        Dancehall Official  37i9dQZF1DXan38dNVDdl4
# 26            Westside Story  37i9dQZF1DWSvKsRPPnv5o
# 27             Power Workout  37i9dQZF1DWUVpAXiEPK8P
# 28                    No Cap  37i9dQZF1DX0Tkc6ltcBfU
# 29             State of Mind  37i9dQZF1DX1YPTAhwehsC
# 30       Alternative Hip-Hop  37i9dQZF1DWTggY0yqBxES
# 31          Workout Twerkout  37i9dQZF1DX0HRj9P7NxeE
# 32                  Big Mood  37i9dQZF1DWT6SJaitNDax
# 33                 New Noise  37i9dQZF1DWT2jS7NwYPVI
# 34               The New Alt  37i9dQZF1DX82GYcclJ3Ug
# 35                Rock Solid  37i9dQZF1DX49jUV2NfGku
# 36                Rock Party  37i9dQZF1DX8FwnYE6PRvL
# 37                  You & Me  37i9dQZF1DX6mvEU1S6INL
# 38             it's alt good  37i9dQZF1DX2SK4ytI2KAZ
# 39                 The Scene  37i9dQZF1DWZkHEX2YHpDV
# 40                    VOLUME  37i9dQZF1DWWJOmJ7nRx0C
# 41        This Is Ryan Adams  37i9dQZF1DZ06evO1nTCV2
# 42    This Is The Black Keys  37i9dQZF1DZ06evO4m87u0
# 36                                       [trap queen]                Latto
# 37           [houston rap, pop, r&b, rap, trap queen]  Megan Thee Stallion
# 38                                       [trap queen]       Big Boss Vette
# 39                                       [trap queen]            Baby Tate
# 40                               [pluggnb, rap, trap]           Young Nudy
# 41                                       [trap queen]            Sexyy Red
# 42                [hip pop, pop, queens hip hop, rap]          Nicki Minaj
# 43                                       [trap queen]            TiaCorine
# 44                                                 []               Icandy
# 45                                         [pop, rap]              Cardi B
# 46                                 [southern hip hop]             GloRilla
# 47                                        [viral rap]              Monaleo
# 48                                       [trap queen]          Lola Brooke
# 49                                  [alternative r&b]              Doechii

# %%
energetic_df2 = spotify_wrapper.getSongsFromPlaylist('5584DfapBVLoEPxDRbs3LJ', '12172606134')
energetic_df2

# %%
energetic_df3 = spotify_wrapper.getSongsFromPlaylist('6xVIKREKYqM5BPuWA5GgHR', '313ujvh27c6qzafirsaeq3sfzrha')
energetic_df3

# %%
energetic_df4 = spotify_wrapper.getSongsFromPlaylist('1uWowJCSnkS5mD5gWMCHFM', 'y1ic7wnqarvronavth09u2nj5')
energetic_df4

# %%
#Energetic Concanation 
energetic_df = pd.concat([energetic_df, energetic_df2, energetic_df3, energetic_df4], ignore_index=True).drop_duplicates(subset=['name'])
energetic_df['mood'] = 'energetic'
energetic_df

# %%
import csv
csv_file_path = 'energetic_df.csv'
energetic_df.to_csv(csv_file_path, index=False)

# %%
happy_df1 = spotify_wrapper.getSongsFromPlaylist('4AnAUkQNrLKlJCInZGSXRO', 'Indiemono')
happy_df1

# %%
happy_df2 = spotify_wrapper.getSongsFromPlaylist('3d67ufMEJnDAd8PBsVBF8m', 'Greatist')
happy_df2

# %%
happy_df3 = spotify_wrapper.getSongsFromPlaylist('7INcD4lmarWTQiDVodjVt4', 'erinellis29')
happy_df3

# %%
happy_df4 = spotify_wrapper.getSongsFromPlaylist('0xwjzo3jXUUexf3bq6XDLL', '1243452256')
happy_df4

# %%
happy_df = pd.concat([happy_df1, happy_df2, happy_df3, happy_df4], ignore_index=True).drop_duplicates(subset=['name'])
happy_df['mood'] = 'happy'
happy_df

# %%
import csv

csv_file_path = 'happy.csv'
happy_df.to_csv(csv_file_path, index=False)

# %%
sad_df1 = spotify_wrapper.getSongsFromPlaylist('54H6xwriYUwWVjPAPXWbiU', '1243452256')
sad_df1

# %%
sad_df2 = spotify_wrapper.getSongsFromPlaylist('5rvOtiM6c7BlA3YrLSbqxc', 'or61qz5w8vna4urp4uqmmvax3')
sad_df2

# %%
sad_df3 = spotify_wrapper.getSongsFromPlaylist('59G9ynvuOY5hKtNdhGmqQ6', 'urmumtehe')
sad_df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sad_df3 = spotify_wrapper.getSongsFromPlaylist('59G9ynvuOY5hKtNdhGmqQ6', 'urmumtehe')
#       2 sad_df3
#
# NameError: name 'spotify_wrapper' is not defined

# %%
sad_df4 = spotify_wrapper.getSongsFromPlaylist('6yYA6aUGp8qUTgQWWYkPkP', 'biels09')
sad_df4

# %%
sad_df = pd.concat([sad_df1, sad_df2, sad_df3, sad_df4], ignore_index=True).drop_duplicates(subset=['name'])
sad_df['mood'] = 'sad'
sad_df

# %%
import csv
csv_file_path = 'sad_df.csv'
sad_df.to_csv(csv_file_path, index=False)

# %%
calm_df1 = spotify_wrapper.getSongsFromPlaylist('1XE7rQIGl1NFtWEAfwn4b9', 'urfodtkfno5m8ydeurmo4l855')
calm_df1

# %%
calm_df2 = spotify_wrapper.getSongsFromPlaylist('6u08x3MsXfaHbl50phdGEe', 'kid8b7zp8sd31vbqqau8ee22y')
calm_df2

# %%
calm_df3 = spotify_wrapper.getSongsFromPlaylist('7lP9dVzRbxGVWw21G0UrV8', 'w0wbella')
calm_df3

# %%
calm_df4 = spotify_wrapper.getSongsFromPlaylist('4whCCQv7k3U2oDIRz1D70s', '70imn70i9npmqw9atv4yirx3a')
calm_df4

# %%
calm_df = pd.concat([calm_df1, calm_df2, calm_df3, calm_df4], ignore_index=True).drop_duplicates(subset=['name'])
calm_df['mood'] = 'calm'
calm_df

# %%
csv_file_path = 'calm_df.csv'
calm_df.to_csv(csv_file_path, index=False)

# %%
import pandas as pd
happy_df_from_csv = pd.read_csv('./Data/song-data/happy.csv')
happy_features = spotify_wrapper.getFeatures(happy_df_from_csv)
happy_features
# Out:
#                                name  acousticness  danceability  energy  \
# 0    Uptown Funk (feat. Bruno Mars)       0.00966         0.853   0.681
# 1               Hooked On A Feeling       0.26100         0.547   0.820
# 2      Music For a Sushi Restaurant       0.25800         0.720   0.715
# 3                            A-Punk       0.01020         0.551   0.821
# 4         Levitating (feat. DaBaby)       0.00883         0.702   0.825
# ..                              ...           ...           ...     ...
# 547                    WASTED ON ME       0.59800         0.712   0.575
# 548                     Cosmic Love       0.14500         0.524   0.803
# 549             Young And Beautiful       0.26200         0.324   0.416
# 550              Summertime Sadness       0.04770         0.566   0.647
# 551                    Breezeblocks       0.09600         0.615   0.658
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0            0.000057    0.0233    -5.003       0.0888  114.989   0.9300
# 1            0.000000    0.3000    -6.728       0.0805  118.208   0.9330
# 2            0.056800    0.1070    -4.652       0.0400  107.041   0.3570
# 3            0.043800    0.1530    -4.489       0.0539  174.923   0.8420
# 4            0.000000    0.0674    -3.787       0.0601  102.977   0.9150
# ..                ...       ...       ...          ...      ...      ...
# 547          0.000167    0.1600    -6.998       0.1190  121.924   0.0749
# 548          0.000191    0.1150    -5.560       0.0366  140.003   0.0827
# 549          0.000037    0.1100    -8.920       0.0368  113.986   0.1510
# 550          0.000000    0.1210    -6.815       0.0335  111.960   0.2200
# 551          0.000911    0.2050    -7.299       0.0343  150.093   0.2930
#
# [552 rows x 10 columns]

# %%
csv_file_path = './Data/feature-data/happy_features.csv'
happy_features.to_csv(csv_file_path, index=False)

# %%
sad_df_from_csv = pd.read_csv('./Data/song-data/sad_df.csv')
sad_features = spotify_wrapper.getFeatures(sad_df_from_csv)
sad_features
# Out:
#                                 name  acousticness  danceability  energy  \
# 0                               July       0.86800         0.708  0.1860
# 1                everything i wanted       0.90200         0.704  0.2250
# 2         Again (feat. XXXTENTACION)       0.18800         0.664  0.7380
# 3                         Slide Away       0.17000         0.530  0.5380
# 4                        Younger Now       0.00129         0.548  0.8730
# ..                               ...           ...           ...     ...
# 711  What A Time (feat. Niall Horan)       0.66200         0.516  0.4670
# 712                 Superficial Love       0.92800         0.477  0.2420
# 713                   favorite crime       0.86600         0.369  0.2720
# 714                my tears ricochet       0.80600         0.456  0.2630
# 715            Chamber of Reflection       0.94100         0.636  0.0795
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0            0.000000    0.0779    -8.953       0.0422   72.541    0.321
# 1            0.657000    0.1060   -14.454       0.0994  120.006    0.243
# 2            0.000058    0.1350    -4.095       0.0338  119.973    0.203
# 3            0.000003    0.2480    -6.672       0.0335  148.051    0.288
# 4            0.000046    0.1380    -4.881       0.0618  121.918    0.328
# ..                ...       ...       ...          ...      ...      ...
# 711          0.000000    0.0853    -6.184       0.0302  132.861    0.386
# 712          0.000000    0.0818    -9.162       0.0529   43.509    0.488
# 713          0.000000    0.1470   -10.497       0.0364  172.929    0.218
# 714          0.000000    0.0749   -10.630       0.0332  129.860    0.111
# 715          0.002670    0.1030   -14.970       0.0353  119.806    0.138
#
# [716 rows x 10 columns]

# %%
sad_features.to_csv(csv_file_path, index=False)

# %%
calm_df_from_csv = pd.read_csv('./Data/song-data/calm_df.csv')
calm_features = spotify_wrapper.getFeatures(calm_df_from_csv)
calm_features
# Out:
#                    name  acousticness  danceability  energy  instrumentalness  \
# 0            Apocalypse      0.019400         0.369   0.467          0.460000
# 1            Space Song      0.233000         0.507   0.790          0.139000
# 2               Runaway      0.629000         0.422   0.302          0.000078
# 3                  Kids      0.508000         0.827   0.660          0.403000
# 4                  July      0.868000         0.708   0.186          0.000000
# ..                  ...           ...           ...     ...               ...
# 587      BIRTH OF VENUS      0.000013         0.433   0.997          0.007460
# 588             Society      0.087800         0.463   0.881          0.553000
# 589  Ayesha X Righteous      0.004190         0.579   0.596          0.726000
# 590             traitor      0.691000         0.380   0.339          0.000000
# 591  Twin Size Mattress      0.005480         0.325   0.867          0.000004
#
#      liveness  loudness  speechiness    tempo  valence
# 0      0.1090    -9.018       0.0274   94.473   0.1740
# 1      0.1450    -7.307       0.0294  147.065   0.6000
# 2      0.1040    -9.214       0.0372  114.089   0.1230
# 3      0.0756    -9.669       0.0337  113.449   0.9040
# 4      0.0779    -8.953       0.0422   72.541   0.3210
# ..        ...       ...          ...      ...      ...
# 587    0.4330    -3.479       0.1810  130.060   0.0695
# 588    0.2230    -3.596       0.0360  120.023   0.0766
# 589    0.1880   -11.551       0.1170   93.499   0.0723
# 590    0.1200    -7.885       0.0338  100.607   0.0849
# 591    0.1030    -5.530       0.0809  144.866   0.3360
#
# [592 rows x 10 columns]

# %%
csv_file_path = './Data/feature-data/calm_features.csv'
calm_features.to_csv(csv_file_path, index=False)

# %%
energetic_df_from_csv = pd.read_csv('./Data/song-data/energetic_df.csv')
energetic_features = spotify_wrapper.getFeatures(energetic_df_from_csv)
energetic_features
# Out:
#                              name  acousticness  danceability  energy  \
# 0         Jackpot (The Him Remix)       0.02100         0.624   0.864
# 1    White Tiger - Single Version       0.22200         0.772   0.582
# 2                          Energy       0.38000         0.747   0.571
# 3                        Our Love       0.18400         0.741   0.773
# 4                     Running Out       0.08560         0.601   0.682
# ..                            ...           ...           ...     ...
# 562                         Shots       0.00887         0.822   0.863
# 563             beibs in the trap       0.24000         0.743   0.571
# 564                         Water       0.61600         0.816   0.245
# 565                         Myron       0.05500         0.771   0.654
# 566                          FEFE       0.08800         0.931   0.387
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0            0.000407     0.233    -5.341       0.0564  122.030    0.400
# 1            0.000088     0.108    -5.140       0.0615  117.856    0.319
# 2            0.000000     0.534    -7.916       0.4780  172.104    0.553
# 3            0.000000     0.135    -6.692       0.0804  125.007    0.383
# 4            0.003840     0.132    -5.905       0.0338   94.999    0.170
# ..                ...       ...       ...          ...      ...      ...
# 562          0.000001     0.122    -2.441       0.0471  128.017    0.174
# 563          0.000000     0.291    -6.054       0.1450  119.054    0.495
# 564          0.000813     0.127   -15.617       0.4140  140.040    0.187
# 565          0.000000     0.214    -6.976       0.2980  155.047    0.573
# 566          0.000000     0.136    -9.127       0.4120  125.978    0.376
#
# [567 rows x 10 columns]

# %%
csv_file_path = './Data/feature-data/energetic_features.csv'
energetic_features.to_csv(csv_file_path, index=False)

# %%
main_df = pd.concat([happy_features, sad_features, calm_features, energetic_features], ignore_index=True).drop_duplicates(subset=['name'])
main_df
# Out:
#                                 name  acousticness  danceability  energy  \
# 0     Uptown Funk (feat. Bruno Mars)       0.00966         0.853   0.681
# 1                Hooked On A Feeling       0.26100         0.547   0.820
# 2       Music For a Sushi Restaurant       0.25800         0.720   0.715
# 3                             A-Punk       0.01020         0.551   0.821
# 4          Levitating (feat. DaBaby)       0.00883         0.702   0.825
# ...                              ...           ...           ...     ...
# 2422                           Shots       0.00887         0.822   0.863
# 2423               beibs in the trap       0.24000         0.743   0.571
# 2424                           Water       0.61600         0.816   0.245
# 2425                           Myron       0.05500         0.771   0.654
# 2426                            FEFE       0.08800         0.931   0.387
#
#       instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0             0.000057    0.0233    -5.003       0.0888  114.989    0.930
# 1             0.000000    0.3000    -6.728       0.0805  118.208    0.933
# 2             0.056800    0.1070    -4.652       0.0400  107.041    0.357
# 3             0.043800    0.1530    -4.489       0.0539  174.923    0.842
# 4             0.000000    0.0674    -3.787       0.0601  102.977    0.915
# ...                ...       ...       ...          ...      ...      ...
# 2422          0.000001    0.1220    -2.441       0.0471  128.017    0.174
# 2423          0.000000    0.2910    -6.054       0.1450  119.054    0.495
# 2424          0.000813    0.1270   -15.617       0.4140  140.040    0.187
# 2425          0.000000    0.2140    -6.976       0.2980  155.047    0.573
# 2426          0.000000    0.1360    -9.127       0.4120  125.978    0.376
#
# [2212 rows x 10 columns]

# %%
csv_file_path = './Data/Training/train.csv'
main_df.to_csv(csv_file_path, index=False)

# %%
#user enters a song
track_name = "22"
artist_name = "Taylor Swift"
results = spotify_wrapper.spotify.search(q=f"track:{track_name} artist:{artist_name}", type='track')
track = results['tracks']['items'][0]
track_uri = track['id']

# %%
track_features = spotify_wrapper.spotify.audio_features([track_uri])
print(track_features)
