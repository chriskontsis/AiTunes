# %%
import SpotifyAPIWrapper
import Visualizer
import pandas as pd
import numpy as np
import spotipy

# %%
spotify_wrapper = SpotifyAPIWrapper.SpotifyAPIWrapper()
user_playlist_df = spotify_wrapper.getUsersPlaylists('chris0927')
user_playlist_df
# Out:
#            name                    uris
# 0  Latin Dinner  37i9dQZF1DX2zAr9vdmFlU
# 1          swag  16gMkLIFb61VznqN1w8gNN
# 2  New Playlist  0aWiePJiqLUV2zyn71th1Z

# %%
#0Vjhah37el0Aq5yoRaujBz
energetic_df = spotify_wrapper.getSongsFromPlaylist('0Vjhah37el0Aq5yoRaujBz', 'Jeffry Harrison')
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0Vjhah37el0Aq5yoRaujBz/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2016-09-14T20:29:48Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1231779322'}, 'href': 'https://api.spotify.com/v1/users/1231779322', 'id': '1231779322', 'type': 'user', 'uri': 'spotify:user:1231779322'}, 'is_local': False, 'primary_color': None, 'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iymigONRODGl6XJIprcuF'}, 'href': 'https://api.spotify.com/v1/artists/7iymigONRODGl6XJIprcuF', 'id': '7iymigONRODGl6XJIprcuF', 'name': 'Jocelyn Alice', 'type': 'artist', 'uri': 'spotify:artist:7iymigONRODGl6XJIprcuF'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/2MqIUTIvZPARqkpFoDX9Fr'}, 'href': 'https://api.spotify.com/v1/albums/2MqIUTIvZPARqkpFoDX9Fr', 'id': '2MqIUTIvZPARqkpFoDX9Fr', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2734a699f2200d8a341ac3b6353', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e024a699f2200d8a341ac3b6353', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048514a699f2200d8a341ac3b6353', 'width': 64}], 'name': 'Jackpot (The Him Remix)', 'release_date': '2016-05-13', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:2MqIUTIvZPARqkpFoDX9Fr'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iymigONRODGl6XJIprcuF'}, 'href': 'https://api.spotify.com/v1/artists/7iymigONRODGl6XJIprcuF', 'id': '7iymigONRODGl6XJIprcuF', 'name': 'Jocelyn Alice', 'type': 'artist', 'uri': 'spotify:artist:7iymigONRODGl6XJIprcuF'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', ...
