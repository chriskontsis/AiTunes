# %%
import SpotifyAPIWrapper
import Visualizer
import pandas as pd
import numpy as np
import spotipy
import time

# %%
spotify_wrapper = SpotifyAPIWrapper.SpotifyAPIWrapper()
user_playlist_df = spotify_wrapper.getUsersPlaylists('70imn70i9npmqw9atv4yirx3a')
user_playlist_df
# Out:
#               name                    uris
# 0        CyberPunk  09GEWE4Bl6UtcHCRak1O3s
# 1  Calm playlist<3  4whCCQv7k3U2oDIRz1D70s

# %%
#0Vjhah37el0Aq5yoRaujBz
energetic_df = spotify_wrapper.getSongsFromPlaylist('0Vjhah37el0Aq5yoRaujBz', 'Jeffry Harrison')
energetic_df
# Out:
#                              name                     uri  \
# 0         Jackpot (The Him Remix)  6NSjdFYF2zxgQ7UvsKoRxy
# 1    White Tiger - Single Version  64I0PKLFEKlcvc7fEVUGq0
# 2                          Energy  79XrkTOfV1AqySNjVlygpW
# 3                        Our Love  4MyyNsp3aBr0SKSKENNpDT
# 4                     Running Out  2H8LPaY3NSjmOFMH2Rygnz
# ..                            ...                     ...
# 301                     Supernova  0sAA3arXOVoczn884kfDpx
# 302      HUMBLE. - SKRILLEX REMIX  65ES1qwOB577ZnTkizMXJJ
# 303            You Got to Love Me  7uRRcR7qb7nJSaLfSQlWiL
# 304    Be Yourself (Extended Mix)  73F14MUC2YyZQn7reIJfEr
# 305                       Apolune  315sgToRVTKGpOVNf8Ak5Q
#
#                                                 genres        artists
# 0                                [canadian electropop]  Jocelyn Alice
# 1                       [chillwave, edm, indietronica]      Izzy Bizu
# 2    [canadian hip hop, canadian pop, hip hop, pop ...          Drake
# 3                                          [afrobeats]    Nico & Vinz
# 4                                                   []         Matoma
# ..                                                 ...            ...
# 301                                                 []      Kai Straw
# 302     [brostep, complextro, edm, electro, pop dance]       Skrillex
# 303  [electronica, hamburg electronic, minimal tech...   DAVID AUGUST
# 304  [french indie pop, french indietronica, new fr...   Kazy Lambist
# 305                                       [indie soul]    Jesper Ryom
#
# [306 rows x 4 columns]

# %%
energetic_df2 = spotify_wrapper.getSongsFromPlaylist('5584DfapBVLoEPxDRbs3LJ', '12172606134')
energetic_df2
# Out:
#                                       name                     uri  \
# 0                                 CARNIVAL  4m4BHvDfzIgj5LbQLuFiIp
# 1                                   redrum  52eIcoLUM25zbQupAZYoFh
# 2                Stand On It (with Future)  7H3lr9bsPBGFx5NyTuBBGc
# 3                       Goosebumps - Remix  5uEYRdEIh9Bo4fpjDd4Na9
# 4                    Dreams and Nightmares  42zd6DYQ4o4SECmTITrM1U
# ..                                     ...                     ...
# 89                               Lifestyle  7DTlsMOQjGysXHpwwpHuPl
# 90                                Daylight  4ZT0wGKwlJRjpMUuwZVy3p
# 91                                 TALKING  3qnbLYCLzKvGIQXFyopS2H
# 92  Dark Knight Dummo (feat. Travis Scott)  1pfwOQKJsRRBf6NdYO4Qog
# 93              Point Em Out (with DaBaby)  1oaV97SzklGWVLi9LdW4Hf
#
#                                                genres          artists
# 0                         [chicago rap, hip hop, rap]       Kanye West
# 1                         [atl hip hop, hip hop, rap]        21 Savage
# 2                                 [pluggnb, rage rap]             Yeat
# 3                          [hip hop, rap, slap house]     Travis Scott
# 4   [hip hop, philly rap, pop rap, rap, southern h...        Meek Mill
# ..                                                ...              ...
# 89                                                 []        Rich Gang
# 90  [canadian hip hop, canadian pop, hip hop, pop ...            Drake
# 91                        [chicago rap, hip hop, rap]       Kanye West
# 92                           [melodic rap, rap, trap]     Trippie Redd
# 93                                  [texas latin rap]  That Mexican OT
#
# [94 rows x 4 columns]

# %%
energetic_df3 = spotify_wrapper.getSongsFromPlaylist('6xVIKREKYqM5BPuWA5GgHR', '313ujvh27c6qzafirsaeq3sfzrha')
energetic_df3
# Out:
#                                 name                     uri  \
# 0                           Payphone  1LmN9SSHISbtp9LoaR5ZVJ
# 1                    I Kissed A Girl  005lwxGU1tms6HGELIcUv9
# 2                               Maps  4gbVRS8gloEluzf0GzDOFc
# 3                       Fire Burning  2oENJa1T33GJ0w8dC167G4
# 4                         Just Dance  2x7MyWybabEz6Y6wvHuwGE
# ..                               ...                     ...
# 82                         Die Young  7EQGXaVSyEDsCWKmUcfpLk
# 83               Best Day Of My Life  5Hroj5K7vLpIG4FNCRIjbP
# 84                I Want It That Way  47BBI51FKFwOMlIiX6m8ya
# 85                       Take It Off  0WCiI0ddWiu5F2kSHgfw5S
# 86  Give Me Everything (feat. Nayer)  4QNpBfC0zvjKqPJcyqBy9W
#
#                              genres           artists
# 0                             [pop]          Maroon 5
# 1                             [pop]        Katy Perry
# 2                             [pop]          Maroon 5
# 3   [dance pop, miami hip hop, pop]     Sean Kingston
# 4         [art pop, dance pop, pop]         Lady Gaga
# ..                              ...               ...
# 82                 [dance pop, pop]             Kesha
# 83          [modern rock, pop rock]  American Authors
# 84       [boy band, dance pop, pop]   Backstreet Boys
# 85                 [dance pop, pop]             Kesha
# 86  [dance pop, miami hip hop, pop]           Pitbull
#
# [87 rows x 4 columns]

# %%
energetic_df4 = spotify_wrapper.getSongsFromPlaylist('1uWowJCSnkS5mD5gWMCHFM', 'y1ic7wnqarvronavth09u2nj5')
energetic_df4
# Out:
#                                 name                     uri  \
# 0         Ballin' (with Roddy Ricch)  3QzAOrNlsabgbMwlZt7TAY
# 1                         SICKO MODE  2xLMifQCjDGFmkHkpNLD9h
# 2                           Mo Bamba  1xzBco0xcoJEDXktl7Jxrr
# 3   Drip Too Hard (Lil Baby & Gunna)  78QR3Wp35dqAhFEc2qAGjE
# 4                         REEL IT IN  5qHirGR7M9tdm6C17DlzSY
# ..                               ...                     ...
# 88                 beibs in the trap  0ESJlaM8CE1jRWaNtwSNj8
# 89                             Water  7EoSDrwBPUBeBEORrpvgko
# 90                             Myron  56uXDJRCuoS7abX3SkzHKQ
# 91       Shoota (feat. Lil Uzi Vert)  2BJSMvOGABRxokHKB0OI8i
# 92                              FEFE  2l8nEO0vsTRCRnGqQty6qx
#
#                                                genres        artists
# 0    [cali rap, pop rap, rap, southern hip hop, trap]        Mustard
# 1                          [hip hop, rap, slap house]   Travis Scott
# 2                                [pop rap, rap, trap]      Sheck Wes
# 3                  [atl hip hop, atl trap, rap, trap]       Lil Baby
# 4   [pop rap, portland hip hop, rap, underground h...          Aminé
# ..                                                ...            ...
# 88                         [hip hop, rap, slap house]   Travis Scott
# 89                                                 []       Ugly God
# 90  [hip hop, melodic rap, philly rap, rage rap, r...   Lil Uzi Vert
# 91       [atl hip hop, plugg, pluggnb, rage rap, rap]  Playboi Carti
# 92                                          [emo rap]        6ix9ine
#
# [93 rows x 4 columns]

# %%
#Energetic Concanation 
energetic_df = pd.concat([energetic_df, energetic_df2, energetic_df3, energetic_df4], ignore_index=True).drop_duplicates(subset=['name'])
energetic_df['mood'] = 'energetic'
energetic_df
# Out:
#                              name                     uri  \
# 0         Jackpot (The Him Remix)  6NSjdFYF2zxgQ7UvsKoRxy
# 1    White Tiger - Single Version  64I0PKLFEKlcvc7fEVUGq0
# 2                          Energy  79XrkTOfV1AqySNjVlygpW
# 3                        Our Love  4MyyNsp3aBr0SKSKENNpDT
# 4                     Running Out  2H8LPaY3NSjmOFMH2Rygnz
# ..                            ...                     ...
# 562                         Shots  7cWNahjynBEP4wuXXhU0m6
# 563             beibs in the trap  0ESJlaM8CE1jRWaNtwSNj8
# 564                         Water  7EoSDrwBPUBeBEORrpvgko
# 565                         Myron  56uXDJRCuoS7abX3SkzHKQ
# 566                          FEFE  2l8nEO0vsTRCRnGqQty6qx
#
#                                                 genres        artists  \
# 0                                [canadian electropop]  Jocelyn Alice
# 1                       [chillwave, edm, indietronica]      Izzy Bizu
# 2    [canadian hip hop, canadian pop, hip hop, pop ...          Drake
# 3                                          [afrobeats]    Nico & Vinz
# 4                                                   []         Matoma
# ..                                                 ...            ...
# 562  [atl hip hop, atlanta bass, crunk, dirty south...        Lil Jon
# 563                         [hip hop, rap, slap house]   Travis Scott
# 564                                                 []       Ugly God
# 565  [hip hop, melodic rap, philly rap, rage rap, r...   Lil Uzi Vert
# 566                                          [emo rap]        6ix9ine
#
#           mood
# 0    energetic
# 1    energetic
# 2    energetic
# 3    energetic
# 4    energetic
# ..         ...
# 562  energetic
# 563  energetic
# 564  energetic
# 565  energetic
# 566  energetic
#
# [567 rows x 5 columns]

# %%
import csv
csv_file_path = 'energetic_df.csv'
energetic_df.to_csv(csv_file_path, index=False)

# %%
happy_df1 = spotify_wrapper.getSongsFromPlaylist('4AnAUkQNrLKlJCInZGSXRO', 'Indiemono')
happy_df1
# Out:
#                                                   name  \
# 0                       Uptown Funk (feat. Bruno Mars)
# 1                                  Hooked On A Feeling
# 2                         Music For a Sushi Restaurant
# 3                                               A-Punk
# 4                            Levitating (feat. DaBaby)
# ..                                                 ...
# 250    You Never Can Tell - 1964 Single Version / Mono
# 251                                            Alright
# 252  A Little Less Conversation - JXL Radio Edit Remix
# 253                                          Strangers
# 254                                     Black Or White
#
#                         uri  \
# 0    4rmPQGwcLQjCoFq5NrTA0D
# 1    6Ac4NVYYl2U73QiTt11ZKd
# 2    5LYMamLv12UPbemOaTPyeV
# 3    5dKBaysNJtfpyNTRa5lqDb
# 4    5nujrmhLynf4yMoMtj8AQF
# ..                      ...
# 250  2LcV5dZWN47XVCVZ1dFwfQ
# 251  5xC8uOesnn0udeXAYlAnoY
# 252  0m7xvX7nhPZ9DOZipTUedd
# 253  3wcluZHyfuTzIXHfwXVAIE
# 254  5YAY2D4s3o0QNOpFwEsynX
#
#                                                 genres          artists
# 0                                           [pop soul]      Mark Ronson
# 1                                [classic swedish pop]       Blue Swede
# 2                                                [pop]     Harry Styles
# 3    [baroque pop, chamber pop, garage rock, indie ...  Vampire Weekend
# 4                             [dance pop, pop, uk pop]         Dua Lipa
# ..                                                 ...              ...
# 250  [blues, blues rock, classic rock, rock, rock-a...      Chuck Berry
# 251          [alternative rock, britpop, oxford indie]       Supergrass
# 252                        [rock-and-roll, rockabilly]    Elvis Presley
# 253                                 [stomp and holler]          Mt. Joy
# 254                                        [r&b, soul]  Michael Jackson
#
# [255 rows x 4 columns]

# %%
happy_df2 = spotify_wrapper.getSongsFromPlaylist('3d67ufMEJnDAd8PBsVBF8m', 'Greatist')
happy_df2
# Out:
#                                name                     uri  \
# 0                You Make My Dreams  0293bTPojlkLvyr8ojc74y
# 1                   How Will I Know  5tdKaKLnC4SgtDZ6RlWeal
# 2     Don't You Worry 'Bout A Thing  4RXZXxI9xvfVUeE7SYDPDV
# 3                     Hakuna Matata  5k3U0OGYBccHdKJJu3HrUN
# 4                             Happy  6NPVjNh8Jhru9xOmyQigds
# 5   In the Summertime (Re-Recorded)  6fOXeZLwVZ1J48d3xz6JnY
# 6           Twistin' The Night Away  3I3W71Hi6zFnXIeGHJuauN
# 7                Love Rollercoaster  6OBeM4d4RGzxcMphQVSgED
# 8                 Send Me on My Way  6hs3SDnbO3f6VQuPO4KBEb
# 9                      I Get Around  3mXexrmtPJ1KdWN37rYePx
# 10           Ain't Too Proud To Beg  22x73BTJpIkciL7605zZ66
# 11                      Love On Top  1z6WtY7X4HQJvzxC4UgkSf
# 12              Walking On Sunshine  05wIrZSwuaVWhcv5FfqeH0
# 13                   Beyond the Sea  2EIaO5knwUA3F2qnf9LV3S
# 14                  Dream of Bombay  0ikd6zPPVvJefH8gN3IuKw
# 15                        The Twist  3ohLnESFgYACPMCkoTOzqE
# 16             Don't Worry Be Happy  4v52HuhZqVV0eNpP6vzH5I
# 17            Tequila (Re-Recorded)  4VkHBfAfYw7TexAMDRDoQq
# 18                   Come On Eileen  0EMmVUYs9ZZRHtlADB88uz
# 19               Once in a Lifetime  1Tr4K5MU5XYE44umXGDndd
#
#                                                genres                  artists
# 0   [album rock, classic rock, heartland rock, mel...  Daryl Hall & John Oates
# 1                                    [dance pop, pop]          Whitney Houston
# 2                                      [motown, soul]            Stevie Wonder
# 3                                       [movie tunes]              Nathan Lane
# 4                                    [dance pop, pop]        Pharrell Williams
# 5                     [british blues, classic uk pop]              Mungo Jerry
# 6                    [classic soul, soul, vocal jazz]                Sam Cooke
# 7   [classic soul, disco, funk, p funk, quiet stor...             Ohio Players
# 8                         [jam band, pittsburgh rock]              Rusted Root
# 9   [baroque pop, classic rock, folk rock, mellow ...           The Beach Boys
# 10         [classic soul, memphis soul, motown, soul]          The Temptations
# 11                                         [pop, r&b]                  Beyoncé
# 12                                     [new wave pop]      Katrina & The Waves
# 13  [adult standards, easy listening, lounge, rock...              Bobby Darin
# 14  [australian garage punk, australian indie, aus...                  Viceroy
# 15                        [rock-and-roll, rockabilly]           Chubby Checker
# 16                                       [a cappella]           Bobby McFerrin
# 17                                                 []               The Champs
# 18             [new romantic, new wave, new wave pop]   Dexys Midnight Runners
# 19  [alternative rock, art punk, dance rock, funk ...            Talking Heads

# %%
happy_df3 = spotify_wrapper.getSongsFromPlaylist('7INcD4lmarWTQiDVodjVt4', 'erinellis29')
happy_df3
# Out:
#                                                   name  \
# 0                 Here Comes The Sun - Remastered 2009
# 1                                    Send Me On My Way
# 2                Signed, Sealed, Delivered (I'm Yours)
# 3                                  Hooked On A Feeling
# 4                       I'm a Believer - 2006 Remaster
# ..                                                 ...
# 231                       Take It Easy - 2013 Remaster
# 232                                Dancing In the Dark
# 233  Sympathy For The Devil - 50th Anniversary Edition
# 234                                      Sweet Emotion
# 235                                           Colorful
#
#                         uri  \
# 0    6dGnYIeXmHdcikdzNNDMm2
# 1    6XK6Zw6JkFsHXzAcMWNiIr
# 2    2eF8pWbiivYsYRpbntYsnc
# 3    2Nz6aF1umHh5Et6I5H581L
# 4    3G7tRC24Uh09Hmp1KZ7LQ2
# ..                      ...
# 231  4yugZvBYaoREkJKtbG08Qr
# 232  7FwBtcecmlpc1sLySPXeGE
# 233  1Ud6moTC0KyXMq1Oxfien0
# 234  73TxYZd0lBCVRrHawrAglA
# 235  2DkxSUXblz5fcctAccM3bl
#
#                                                 genres  \
# 0    [british invasion, classic rock, merseybeat, p...
# 1                          [jam band, pittsburgh rock]
# 2                                       [motown, soul]
# 3                                [classic swedish pop]
# 4    [album rock, beatlesque, bubblegum pop, classi...
# ..                                                 ...
# 231  [album rock, classic rock, heartland rock, mel...
# 232  [heartland rock, mellow gold, permanent wave, ...
# 233  [album rock, british invasion, classic rock, r...
# 234        [album rock, classic rock, hard rock, rock]
# 235                                                 []
#
#                          artists
# 0                    The Beatles
# 1                    Rusted Root
# 2                  Stevie Wonder
# 3                     Blue Swede
# 4                    The Monkees
# ..                           ...
# 231                       Eagles
# 232            Bruce Springsteen
# 233           The Rolling Stones
# 234                    Aerosmith
# 235  Rocco DeLuca and The Burden
#
# [236 rows x 4 columns]

# %%
happy_df4 = spotify_wrapper.getSongsFromPlaylist('0xwjzo3jXUUexf3bq6XDLL', '1243452256')
happy_df4
# Out:
#                                  name                     uri  \
# 0                       Midnight City  1eyzqe2QqGZUmfcPZtrIyt
# 1                         Tongue Tied  0GO8y8jQk1PkHzS31d699N
# 2   Slide (feat. Frank Ocean & Migos)  7tr2za8SQg2CI8EDgrdtNl
# 3                   Send Me On My Way  6XK6Zw6JkFsHXzAcMWNiIr
# 4                         Sunday Best  1Cv1YLb4q0RzL6pybtaMLo
# ..                                ...                     ...
# 75                        Cosmic Love  0CSTvWUps1YmpQoXXay9ol
# 76                  Dog Days Are Over  1YLJVmuzeM2YSUkCCaTNUB
# 77                Young And Beautiful  2nMeu6UenVvwUktBCpLMK9
# 78                 Summertime Sadness  1Ist6PR2BZR3n2z2Y5R6S1
# 79                       Breezeblocks  3n69hLUdIsSa1WlRmjMZlW
#
#                                                genres                 artists
# 0   [french shoegaze, french synthpop, indietronic...                     M83
# 1   [indie rock, la indie, modern alternative rock...               GROUPLOVE
# 2   [dance pop, edm, electro house, house, pop, po...           Calvin Harris
# 3                         [jam band, pittsburgh rock]             Rusted Root
# 4                                      [bedroom soul]                Surfaces
# ..                                                ...                     ...
# 75  [baroque pop, electropop, modern rock, uk alte...  Florence + The Machine
# 76  [baroque pop, electropop, modern rock, uk alte...  Florence + The Machine
# 77                                     [art pop, pop]            Lana Del Rey
# 78                                     [art pop, pop]            Lana Del Rey
# 79  [indie rock, indietronica, modern alternative ...                   alt-J
#
# [80 rows x 4 columns]

# %%
happy_df = pd.concat([happy_df1, happy_df2, happy_df3, happy_df4], ignore_index=True).drop_duplicates(subset=['name'])
happy_df['mood'] = 'happy'
happy_df
# Out:
#                                name                     uri  \
# 0    Uptown Funk (feat. Bruno Mars)  4rmPQGwcLQjCoFq5NrTA0D
# 1               Hooked On A Feeling  6Ac4NVYYl2U73QiTt11ZKd
# 2      Music For a Sushi Restaurant  5LYMamLv12UPbemOaTPyeV
# 3                            A-Punk  5dKBaysNJtfpyNTRa5lqDb
# 4         Levitating (feat. DaBaby)  5nujrmhLynf4yMoMtj8AQF
# ..                              ...                     ...
# 585                    WASTED ON ME  6tXebnSmy1ZEZANFRHRoCO
# 586                     Cosmic Love  0CSTvWUps1YmpQoXXay9ol
# 588             Young And Beautiful  2nMeu6UenVvwUktBCpLMK9
# 589              Summertime Sadness  1Ist6PR2BZR3n2z2Y5R6S1
# 590                    Breezeblocks  3n69hLUdIsSa1WlRmjMZlW
#
#                                                 genres  \
# 0                                           [pop soul]
# 1                                [classic swedish pop]
# 2                                                [pop]
# 3    [baroque pop, chamber pop, garage rock, indie ...
# 4                             [dance pop, pop, uk pop]
# ..                                                 ...
# 585                                    [stutter house]
# 586  [baroque pop, electropop, modern rock, uk alte...
# 588                                     [art pop, pop]
# 589                                     [art pop, pop]
# 590  [indie rock, indietronica, modern alternative ...
#
#                     artists   mood
# 0               Mark Ronson  happy
# 1                Blue Swede  happy
# 2              Harry Styles  happy
# 3           Vampire Weekend  happy
# 4                  Dua Lipa  happy
# ..                      ...    ...
# 585               Angrybaby  happy
# 586  Florence + The Machine  happy
# 588            Lana Del Rey  happy
# 589            Lana Del Rey  happy
# 590                   alt-J  happy
#
# [552 rows x 5 columns]

# %%
import csv

csv_file_path = 'happy.csv'
happy_df.to_csv(csv_file_path, index=False)

# %%
sad_df1 = spotify_wrapper.getSongsFromPlaylist('54H6xwriYUwWVjPAPXWbiU', '1243452256')
sad_df1
# Out:
#                                name                     uri  \
# 0                              July  5a6pdCHlWS2ekOOQ70QnAr
# 1               everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ
# 2        Again (feat. XXXTENTACION)  2S2od3hT7ceytw7d1pTRuE
# 3                        Slide Away  44ADyYoY5liaRa3EOAl4uf
# 4                       Younger Now  2fGxYYMQbVqgIdaqfz2OwA
# ..                              ...                     ...
# 181             Young And Beautiful  2nMeu6UenVvwUktBCpLMK9
# 182                      ocean eyes  2uIX8YMNjGMD7441kqyyNU
# 183                           Youth  0UPMxtinlgA1dkne9PAKTW
# 184                       Fine Line  6VzcQuzTNTMFnJ6rBSaLH9
# 185  Boys Of Faith (feat. Bon Iver)  6pRRHgDjfIGhTUCGlHX2p8
#
#                               genres        artists
# 0                       [alt z, pop]     Noah Cyrus
# 1                     [art pop, pop]  Billie Eilish
# 2                       [alt z, pop]     Noah Cyrus
# 3                              [pop]    Miley Cyrus
# 4                              [pop]    Miley Cyrus
# ..                               ...            ...
# 181                   [art pop, pop]   Lana Del Rey
# 182                   [art pop, pop]  Billie Eilish
# 183  [neo mellow, singer-songwriter]       Daughter
# 184                            [pop]   Harry Styles
# 185       [classic oklahoma country]     Zach Bryan
#
# [186 rows x 4 columns]

# %%
sad_df2 = spotify_wrapper.getSongsFromPlaylist('5rvOtiM6c7BlA3YrLSbqxc', 'or61qz5w8vna4urp4uqmmvax3')
sad_df2
# Out:
#                                          name                     uri  \
# 0                Dandelions - slowed + reverb  6fhG2KJgwO7CrNflRaRmvp
# 1                Sure Thing - slowed + reverb  5ai3UwdgwPp9wGcHY1zAk1
# 2                              hotline (edit)  0WFryfbNKPXVtVQlz5dZ8H
# 3    Another Love but it's Slowed and Muffled  0G52ehW8DnvcmjplHwzEkI
# 4                                Broken Heart  4ZX8leOyXCg8pjBUpMjp26
# ..                                        ...                     ...
# 191                                 Sad Hours  1f5gQuy8aQEj6WX9wc8i3k
# 192       happier than ever (slowed + reverb)  0sN7p06rSdZtTjZIomFWyq
# 193      i don't like it, you're not the same  3qN62DlOJoIMWFGPVxilxU
# 194        Everybody Dies In Their Nightmares  3GVkPk8mqxz0itaAriG1L7
# 195   sex money feelings die - slowed version  0dkvbYmXYEPK7gGMdytmfI
#
#                                                 genres            artists
# 0    [alt z, canadian contemporary r&b, canadian po...            Ruth B.
# 1                            [r&b, urban contemporary]             Miguel
# 2                                       [art pop, pop]      Billie Eilish
# 3                         [slowed and reverb, sped up]            Dybbukk
# 4    [french indie pop, french indietronica, french...               Syna
# ..                                                 ...                ...
# 191                           [lo-fi chill, sad lo-fi]          LRN Slime
# 192                                [slowed and reverb]  z e r o t o n i n
# 193        [lo-fi chill, sad lo-fi, slowed and reverb]             meynus
# 194                      [emo rap, miami hip hop, rap]       XXXTENTACION
# 195  [electropop, indietronica, neo-synthpop, swedi...           Lykke Li
#
# [196 rows x 4 columns]

# %%
sad_df3 = spotify_wrapper.getSongsFromPlaylist('59G9ynvuOY5hKtNdhGmqQ6', 'urmumtehe')
sad_df3
# Out:
#                                 name                     uri  \
# 0                      Glimpse of Us  6xGruZOHLs39ZbVccQTuPZ
# 1           SLOW DANCING IN THE DARK  0rKtyWc8bvkriBthvHKY8d
# 2                        Like You Do  1MONUudxAjEk76FJvzGhuD
# 3        worldstar money (interlude)  0baNzeUcPQnQSagpe8T0mD
# 4                               Hope  2ZRo7axmMPeSVUvDbGkJah
# ..                               ...                     ...
# 269  Killing Me Softly With His Song  0Q0IVlqMV64kNLlwjPj0Hl
# 270           Fall in Love with You.  4kJT7Yj6Za01KfKHjb7mZE
# 271                               K.  1FWsomP9StpCcXNWmJk8Cl
# 272                       Let Her Go  1KxwZYyzWNyZSRyErj2ojT
# 273                          Qamarun  5Msgfzc4JXEfqNj0t8RzyT
#
#                                                 genres               artists
# 0                                          [viral pop]                  Joji
# 1                                          [viral pop]                  Joji
# 2                                          [viral pop]                  Joji
# 3                                          [viral pop]                  Joji
# 4                        [emo rap, miami hip hop, rap]          XXXTENTACION
# ..                                                 ...                   ...
# 269  [east coast hip hop, hip hop, neo soul, new je...                Fugees
# 270                                   [pittsburgh rap]          Montell Fish
# 271  [ambient pop, dream pop, el paso indie, shoegaze]  Cigarettes After Sex
# 272  [alternative metal, nu metal, rap metal, rock,...             Passenger
# 273                             [malayalam madh, naat]   Ayisha Abdul Basith
#
# [274 rows x 4 columns]

# %%
sad_df4 = spotify_wrapper.getSongsFromPlaylist('6yYA6aUGp8qUTgQWWYkPkP', 'biels09')
sad_df4
# Out:
#                                           name                     uri  \
# 0                                   Your Power  042Sl6Mn83JHyLEqdK7uI0
# 1    i hate u, i love u (feat. olivia o'brien)  7vRriwrloYVaoAe3a9wJHe
# 2                                      Bruises  4Of7rzpRpV1mWRbhp5rAqG
# 3                          you were good to me  4CxFN5zON70B3VOPBYbd6P
# 4                              drivers license  5wANPM4fQCJwkGd4rN57mH
# ..                                         ...                     ...
# 186                              Say Something  6Vc5wAMmXdKIAM7WUoEb7N
# 187                           Love In The Dark  7B5Npv8NjjTCzk8PLpU66h
# 188                     Hold Me While You Wait  60iSKGrGazRzICtMjADNSM
# 189                         When We Were Young  7GgWAITsYJaRM3r50rfh5w
# 190                      Chamber of Reflection  1rcnbeovJnCUHDwImmpTNp
#
#                                             genres             artists
# 0                                   [art pop, pop]       Billie Eilish
# 1                                            [pop]               gnash
# 2                                    [pop, uk pop]       Lewis Capaldi
# 3                         [alt z, electropop, pop]       Jeremy Zucker
# 4                                            [pop]      Olivia Rodrigo
# ..                                             ...                 ...
# 186  [neo mellow, piano rock, pop rock, viral pop]   A Great Big World
# 187          [british soul, pop, pop soul, uk pop]               Adele
# 188                                  [pop, uk pop]       Lewis Capaldi
# 189          [british soul, pop, pop soul, uk pop]               Adele
# 190                                             []  Your Anxiety Buddy
#
# [191 rows x 4 columns]

# %%
sad_df = pd.concat([sad_df1, sad_df2, sad_df3, sad_df4], ignore_index=True).drop_duplicates(subset=['name'])
sad_df['mood'] = 'sad'
sad_df
# Out:
#                                 name                     uri  \
# 0                               July  5a6pdCHlWS2ekOOQ70QnAr
# 1                everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ
# 2         Again (feat. XXXTENTACION)  2S2od3hT7ceytw7d1pTRuE
# 3                         Slide Away  44ADyYoY5liaRa3EOAl4uf
# 4                        Younger Now  2fGxYYMQbVqgIdaqfz2OwA
# ..                               ...                     ...
# 833  What A Time (feat. Niall Horan)  5WtfUKzXircvW8l5aaVZWT
# 836                 Superficial Love  5hwh37sTi84MVhCBMWzhGE
# 839                   favorite crime  5JCoSi02qi3jJeHdZXMmR8
# 841                my tears ricochet  1MgV7FIyNxIG7WzMRJV5HC
# 846            Chamber of Reflection  1rcnbeovJnCUHDwImmpTNp
#
#                                                 genres             artists  \
# 0                                         [alt z, pop]          Noah Cyrus
# 1                                       [art pop, pop]       Billie Eilish
# 2                                         [alt z, pop]          Noah Cyrus
# 3                                                [pop]         Miley Cyrus
# 4                                                [pop]         Miley Cyrus
# ..                                                 ...                 ...
# 833                                              [pop]      Julia Michaels
# 836  [alt z, canadian contemporary r&b, canadian po...             Ruth B.
# 839                                              [pop]      Olivia Rodrigo
# 841                                              [pop]        Taylor Swift
# 846                                                 []  Your Anxiety Buddy
#
#     mood
# 0    sad
# 1    sad
# 2    sad
# 3    sad
# 4    sad
# ..   ...
# 833  sad
# 836  sad
# 839  sad
# 841  sad
# 846  sad
#
# [716 rows x 5 columns]

# %%
import csv
csv_file_path = 'sad_df.csv'
sad_df.to_csv(csv_file_path, index=False)

# %%
calm_df1 = spotify_wrapper.getSongsFromPlaylist('1XE7rQIGl1NFtWEAfwn4b9', 'urfodtkfno5m8ydeurmo4l855')
calm_df1
# Out:
#                     name                     uri  \
# 0             Apocalypse  3AVrVz5rK8Hrqo9YGiVGN5
# 1             Space Song  1ZgMsA55GIY7ICkQh5MILA
# 2                Runaway  1v1oIWf2Xgh54kIWuKsDf6
# 3                   Kids  6ixkZ2Q9gQeh52C6GxbETg
# 4                   July  5a6pdCHlWS2ekOOQ70QnAr
# ..                   ...                     ...
# 238               Advice  4iUqq3ge3oGsYiPPor64Wh
# 239  Cigarette Daydreams  6jHvX8ZnHKC1PnrPMJ0Emt
# 240                  4am  75enpZYDT6k0PNKu6SJ4W5
# 241          Show Me How  75IQVo8hqI1iwVZyvkN2VT
# 242               Riff 2  2odJoPhzYu2NwEhxN2foal
#
#                                                 genres               artists
# 0    [ambient pop, dream pop, el paso indie, shoegaze]  Cigarettes After Sex
# 1    [baltimore indie, dream pop, dreamo, indie roc...           Beach House
# 2                             [art pop, norwegian pop]                AURORA
# 3                            [lo-fi indie, pov: indie]          Current Joys
# 4                                         [alt z, pop]            Noah Cyrus
# ..                                                 ...                   ...
# 238                                                 []                Alex G
# 239  [modern alternative rock, modern rock, pov: in...     Cage The Elephant
# 240  [bedroom pop, indie pop, norwegian indie, pov:...           girl in red
# 241                            [indie pop, pov: indie]           Men I Trust
# 242                                        [chill pop]        Flawed Mangoes
#
# [243 rows x 4 columns]

# %%
calm_df2 = spotify_wrapper.getSongsFromPlaylist('6u08x3MsXfaHbl50phdGEe', 'kid8b7zp8sd31vbqqau8ee22y')
calm_df2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 calm_df2 = spotify_wrapper.getSongsFromPlaylist('6u08x3MsXfaHbl50phdGEe', 'kid8b7zp8sd31vbqqau8ee22y')
#       2 calm_df2
#
# File ~/Desktop/AiTunes/Reccomender/SpotifyAPIWrapper.py:63, in SpotifyAPIWrapper.getSongsFromPlaylist(self, uri, username, name)
#      61 results = self.spotify.user_playlist(username, uri)
#      62 tracks = results['tracks']
# ---> 63 song_list.extend(self.getName(tracks, song_list))
#      65 while(tracks['next']):
#      66     tracks = self.spotify.next(tracks)
#
# File ~/Desktop/AiTunes/Reccomender/SpotifyAPIWrapper.py:52, in SpotifyAPIWrapper.getName(self, tracks, song_list)
#      50 result = self.spotify.search(artist_name)
#      51 track = result['tracks']['items'][0]
# ---> 52 artist = self.spotify.artist(track["artists"][0]["external_urls"]["spotify"])
#      53 genres = artist["genres"]
#      54 track_data.append((song_name, uri.split(':')[2], genres, artist_name))
#
# File /usr/local/lib/python3.11/site-packages/spotipy/client.py:392, in Spotify.artist(self, artist_id)
#     385 """ returns a single artist given the artist's ID, URI or URL
#     386
#     387     Parameters:
#     388         - artist_id - an artist ID, URI or URL
#     389 """
#     391 trid = self._get_id("artist", artist_id)
# --> 392 return self._get("artists/" + trid)
#
# File /usr/local/lib/python3.11/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File /usr/local/lib/python3.11/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:943, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     940     return response
#     942 response.drain_conn()
# --> 943 retries.sleep(response)
#     944 log.debug("Retry: %s", url)
#     945 return self.urlopen(
#     946     method,
#     947     url,
#    (...)
#     960     **response_kw,
#     961 )
#
# File /usr/local/lib/python3.11/site-packages/urllib3/util/retry.py:355, in Retry.sleep(self, response)
#     346 """Sleep between retry attempts.
#     347
#     348 This method will respect a server's ``Retry-After`` response header
#    (...)
#     351 this method will return immediately.
#     352 """
#     354 if self.respect_retry_after_header and response:
# --> 355     slept = self.sleep_for_retry(response)
#     356     if slept:
#     357         return
#
# File /usr/local/lib/python3.11/site-packages/urllib3/util/retry.py:334, in Retry.sleep_for_retry(self, response)
#     332 retry_after = self.get_retry_after(response)
#     333 if retry_after:
# --> 334     time.sleep(retry_after)
#     335     return True
#     337 return False
#
# KeyboardInterrupt:

# %%
calm_df3 = spotify_wrapper.getSongsFromPlaylist('7lP9dVzRbxGVWw21G0UrV8', 'w0wbella')
calm_df3
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 calm_df3 = spotify_wrapper.getSongsFromPlaylist('7lP9dVzRbxGVWw21G0UrV8', 'w0wbella')
#       2 calm_df3
#
# File ~/Desktop/AiTunes/Reccomender/SpotifyAPIWrapper.py:63, in SpotifyAPIWrapper.getSongsFromPlaylist(self, uri, username, name)
#      61 results = self.spotify.user_playlist(username, uri)
#      62 tracks = results['tracks']
# ---> 63 song_list.extend(self.getName(tracks, song_list))
#      65 while(tracks['next']):
#      66     tracks = self.spotify.next(tracks)
#
# File ~/Desktop/AiTunes/Reccomender/SpotifyAPIWrapper.py:52, in SpotifyAPIWrapper.getName(self, tracks, song_list)
#      50 result = self.spotify.search(artist_name)
#      51 track = result['tracks']['items'][0]
# ---> 52 artist = self.spotify.artist(track["artists"][0]["external_urls"]["spotify"])
#      53 genres = artist["genres"]
#      54 track_data.append((song_name, uri.split(':')[2], genres, artist_name))
#
# File /usr/local/lib/python3.11/site-packages/spotipy/client.py:392, in Spotify.artist(self, artist_id)
#     385 """ returns a single artist given the artist's ID, URI or URL
#     386
#     387     Parameters:
#     388         - artist_id - an artist ID, URI or URL
#     389 """
#     391 trid = self._get_id("artist", artist_id)
# --> 392 return self._get("artists/" + trid)
#
# File /usr/local/lib/python3.11/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File /usr/local/lib/python3.11/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:943, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     940     return response
#     942 response.drain_conn()
# --> 943 retries.sleep(response)
#     944 log.debug("Retry: %s", url)
#     945 return self.urlopen(
#     946     method,
#     947     url,
#    (...)
#     960     **response_kw,
#     961 )
#
# File /usr/local/lib/python3.11/site-packages/urllib3/util/retry.py:355, in Retry.sleep(self, response)
#     346 """Sleep between retry attempts.
#     347
#     348 This method will respect a server's ``Retry-After`` response header
#    (...)
#     351 this method will return immediately.
#     352 """
#     354 if self.respect_retry_after_header and response:
# --> 355     slept = self.sleep_for_retry(response)
#     356     if slept:
#     357         return
#
# File /usr/local/lib/python3.11/site-packages/urllib3/util/retry.py:334, in Retry.sleep_for_retry(self, response)
#     332 retry_after = self.get_retry_after(response)
#     333 if retry_after:
# --> 334     time.sleep(retry_after)
#     335     return True
#     337 return False
#
# KeyboardInterrupt:

# %%
calm_df4 = spotify_wrapper.getSongsFromPlaylist('4whCCQv7k3U2oDIRz1D70s', '70imn70i9npmqw9atv4yirx3a')
calm_df4
# Out:
#                                 name                     uri  \
# 0                              Young  1KIJclzEbNhSVw8tiHPWwE
# 1                         Bubble Gum  3zksbXteOCeSusJ5Xltr3t
# 2                         i love you  6CcJMwBtXByIz4zQLzFkKc
# 3                            Riptide  3JvrhDOgAt6p7K8mDyZwRd
# 4                       Stressed Out  3CRDbSIZ4r5MsZ0YwxuEkn
# ..                               ...                     ...
# 173                          Society  5NLdlIggmKj4G7RB6l8Tm1
# 174               Ayesha X Righteous  4RclU4ut2lgVzkdiZ97cV5
# 175  Everything Works Out in the End  45IFvFqHG8oiEK1fAYdNw1
# 176                          traitor  5CZ40GBx1sQ9agT82CLQCT
# 177               Twin Size Mattress  4LKp7Whi6HvHCsBlftJr9m
#
#                                    genres            artists
# 0       [newcastle nsw indie, pov: indie]          Vacations
# 1    [bedroom pop, indie pop, pov: indie]             Clairo
# 2                          [art pop, pop]      Billie Eilish
# 3                 [folk-pop, modern rock]          Vance Joy
# 4    [modern rock, pop, pov: indie, rock]  Twenty One Pilots
# ..                                    ...                ...
# 173                                    []           Pathetic
# 174                                    []           serioity
# 175  [irish pop, modern rock, neo mellow]           Kodaline
# 176                                 [pop]     Olivia Rodrigo
# 177         [alternative emo, pov: indie]  The Front Bottoms
#
# [178 rows x 4 columns]

# %%
calm_df = pd.concat([calm_df1, calm_df2, calm_df3, calm_df4], ignore_index=True).drop_duplicates(subset=['name'])
calm_df['mood'] = 'calm'
calm_df
# Out:
#                    name                     uri  \
# 0            Apocalypse  3AVrVz5rK8Hrqo9YGiVGN5
# 1            Space Song  1ZgMsA55GIY7ICkQh5MILA
# 2               Runaway  1v1oIWf2Xgh54kIWuKsDf6
# 3                  Kids  6ixkZ2Q9gQeh52C6GxbETg
# 4                  July  5a6pdCHlWS2ekOOQ70QnAr
# ..                  ...                     ...
# 719      BIRTH OF VENUS  1Q98DdOmQlFrIaldR4MOVl
# 720             Society  5NLdlIggmKj4G7RB6l8Tm1
# 721  Ayesha X Righteous  4RclU4ut2lgVzkdiZ97cV5
# 723             traitor  5CZ40GBx1sQ9agT82CLQCT
# 724  Twin Size Mattress  4LKp7Whi6HvHCsBlftJr9m
#
#                                                 genres               artists  \
# 0    [ambient pop, dream pop, el paso indie, shoegaze]  Cigarettes After Sex
# 1    [baltimore indie, dream pop, dreamo, indie roc...           Beach House
# 2                             [art pop, norwegian pop]                AURORA
# 3                            [lo-fi indie, pov: indie]          Current Joys
# 4                                         [alt z, pop]            Noah Cyrus
# ..                                                 ...                   ...
# 719                                        [viral rap]               Banshee
# 720                                                 []              Pathetic
# 721                                                 []              serioity
# 723                                              [pop]        Olivia Rodrigo
# 724                      [alternative emo, pov: indie]     The Front Bottoms
#
#      mood
# 0    calm
# 1    calm
# 2    calm
# 3    calm
# 4    calm
# ..    ...
# 719  calm
# 720  calm
# 721  calm
# 723  calm
# 724  calm
#
# [593 rows x 5 columns]

# %%
happy_features = spotify_wrapper.getFeatures(happy_df)
happy_features
# Out:
#                                name  acousticness  danceability  energy  \
# 0    Uptown Funk (feat. Bruno Mars)       0.00966         0.853   0.681
# 1               Hooked On A Feeling       0.26100         0.547   0.820
# 2      Music For a Sushi Restaurant       0.25800         0.720   0.715
# 3                            A-Punk       0.01020         0.551   0.821
# 4         Levitating (feat. DaBaby)       0.00883         0.702   0.825
# ..                              ...           ...           ...     ...
# 547                    WASTED ON ME       0.59800         0.712   0.575
# 548                     Cosmic Love       0.14500         0.524   0.803
# 549             Young And Beautiful       0.26200         0.324   0.416
# 550              Summertime Sadness       0.04770         0.566   0.647
# 551                    Breezeblocks       0.09600         0.615   0.658
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0            0.000057    0.0233    -5.003       0.0888  114.989   0.9300
# 1            0.000000    0.3000    -6.728       0.0805  118.208   0.9330
# 2            0.056800    0.1070    -4.652       0.0400  107.041   0.3570
# 3            0.043800    0.1530    -4.489       0.0539  174.923   0.8420
# 4            0.000000    0.0674    -3.787       0.0601  102.977   0.9150
# ..                ...       ...       ...          ...      ...      ...
# 547          0.000167    0.1600    -6.998       0.1190  121.924   0.0749
# 548          0.000191    0.1150    -5.560       0.0366  140.003   0.0827
# 549          0.000037    0.1100    -8.920       0.0368  113.986   0.1510
# 550          0.000000    0.1210    -6.815       0.0335  111.960   0.2200
# 551          0.000911    0.2050    -7.299       0.0343  150.093   0.2930
#
# [552 rows x 10 columns]

# %%
sad_features = spotify_wrapper.getFeatures(sad_df)
sad_features
# Out:
#                              name  acousticness  danceability  energy  \
# 0                            July       0.86800         0.708   0.186
# 1             everything i wanted       0.90200         0.704   0.225
# 2      Again (feat. XXXTENTACION)       0.18800         0.664   0.738
# 3                      Slide Away       0.17000         0.530   0.538
# 4                     Younger Now       0.00129         0.548   0.873
# ..                            ...           ...           ...     ...
# 699  1 step forward, 3 steps back       0.94100         0.473   0.203
# 700                    A Year Ago       0.58700         0.548   0.474
# 701           emails i can’t send       0.75700         0.515   0.387
# 702             this is me trying       0.31400         0.515   0.476
# 703                      Hurtless       0.18600         0.370   0.559
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0            0.000000    0.0779    -8.953       0.0422   72.541    0.321
# 1            0.657000    0.1060   -14.454       0.0994  120.006    0.243
# 2            0.000058    0.1350    -4.095       0.0338  119.973    0.203
# 3            0.000003    0.2480    -6.672       0.0335  148.051    0.288
# 4            0.000046    0.1380    -4.881       0.0618  121.918    0.328
# ..                ...       ...       ...          ...      ...      ...
# 699          0.000000    0.1260   -12.627       0.1020  168.884    0.419
# 700          0.000000    0.1210    -8.743       0.0446  119.986    0.261
# 701          0.000000    0.6220   -10.614       0.1920   86.313    0.408
# 702          0.000047    0.1710    -9.843       0.0328  135.886    0.412
# 703          0.000000    0.1210    -5.589       0.0526  162.816    0.316
#
# [704 rows x 10 columns]

# %%
calm_features = spotify_wrapper.getFeatures(calm_df)
calm_features
# Out:
#                    name  acousticness  danceability  energy  instrumentalness  \
# 0            Apocalypse      0.019400         0.369   0.467          0.460000
# 1            Space Song      0.233000         0.507   0.790          0.139000
# 2               Runaway      0.629000         0.422   0.302          0.000078
# 3                  Kids      0.508000         0.827   0.660          0.403000
# 4                  July      0.868000         0.708   0.186          0.000000
# ..                  ...           ...           ...     ...               ...
# 588      BIRTH OF VENUS      0.000013         0.433   0.997          0.007460
# 589             Society      0.087800         0.463   0.881          0.553000
# 590  Ayesha X Righteous      0.004190         0.579   0.596          0.726000
# 591             traitor      0.691000         0.380   0.339          0.000000
# 592  Twin Size Mattress      0.005480         0.325   0.867          0.000004
#
#      liveness  loudness  speechiness    tempo  valence
# 0      0.1090    -9.018       0.0274   94.473   0.1740
# 1      0.1450    -7.307       0.0294  147.065   0.6000
# 2      0.1040    -9.214       0.0372  114.089   0.1230
# 3      0.0756    -9.669       0.0337  113.449   0.9040
# 4      0.0779    -8.953       0.0422   72.541   0.3210
# ..        ...       ...          ...      ...      ...
# 588    0.4330    -3.479       0.1810  130.060   0.0695
# 589    0.2230    -3.596       0.0360  120.023   0.0766
# 590    0.1880   -11.551       0.1170   93.499   0.0723
# 591    0.1200    -7.885       0.0338  100.607   0.0849
# 592    0.1030    -5.530       0.0809  144.866   0.3360
#
# [593 rows x 10 columns]

# %%
energetic_features = spotify_wrapper.getFeatures(energetic_df)
energetic_features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 energetic_features = spotify_wrapper.getFeatures(energetic_df)
#       2 energetic_features
#
# NameError: name 'energetic_df' is not defined

# %%
main_df = pd.concat([happy_features, sad_features, calm_features, energetic_features], ignore_index=True).drop_duplicates(subset=['name'])
main_df
